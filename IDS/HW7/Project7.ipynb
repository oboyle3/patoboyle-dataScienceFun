# %%
import pandas as pd
import numpy as np

# %%
data1= pd.read_csv("https://raw.githubusercontent.com/oboyle3/patoboyle-dataScienceFun/main/IDS/HW7/dermatology%20(1).csv")

# %%
data1

# %%
# Are there any columns with missing values?
data1.isnull().values.any()
# Out:
# True

# %%
print(data1.columns)
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'pnl_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'age', 'class'],
#       dtype='object')

# %%
#
data1.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# pnl_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
import matplotlib.pyplot as plt

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html
data1.boxplot(column=['age'], by=['class'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#Plot the distribution of disease vs. age in order to understand the relationship between the two (use the same format as shown below)
import seaborn as sns
sns.boxplot(data = data1,x = 'class', y ='age')

# %% [markdown]
# some text

# %%
#Use contingency tables to determine which ordinal attributes have the most leverage on disease. Plot the obtained results.
import pandas as pd
contigencyTable1= pd.crosstab(data1['erythema'],data1['class'])
contigencyTable1
# Out:
# class      1   2   3   4   5   6
# erythema
# 0          1   0   1   0   2   0
# 1          7   5   7  11  25   2
# 2         63  34  49  32  22  15
# 3         41  22  15   6   3   3

# %%
# Plot the obtained results
boxplot=contigencyTable1.plot.bar(rot=1)
boxplot

# %%
# 2
contigencyTable2= pd.crosstab(data1['scaling'],data1['class'])
contigencyTable2
# Out:
# class     1   2   3   4   5   6
# scaling
# 0         0   0   2   0   6   0
# 1        13   7  28  24  34   5
# 2        64  43  37  25  11  15
# 3        35  11   5   0   1   0

# %%
# Plot the obtained results #scaling
boxplot=contigencyTable2.plot.bar(rot=1)
boxplot

# %%
#3
#itching
contigencyTable3= pd.crosstab(data1['itching'],data1['class'])
contigencyTable3
# Out:
# class     1   2   3   4   5   6
# itching
# 0        55   9   2  33   8  11
# 1        22  16   9  10   7   8
# 2        21  25  28   5  20   1
# 3        14  11  33   1  17   0

# %%
#3
# Plot the obtained results #itching
boxplot=contigencyTable3.plot.bar(rot=1)
boxplot

# %%
#4 definite_borders
contigencyTable4= pd.crosstab(data1['definite_borders'],data1['class'])
contigencyTable4
# Out:
# class              1   2   3   4   5  6
# definite_borders
# 0                  0  21   1   9  23  5
# 1                 14  22  10  22  16  9
# 2                 73  18  42  18  11  6
# 3                 25   0  19   0   2  0

# %%
#4
# Plot the obtained results #definite_borders
boxplot=contigencyTable4.plot.bar(rot=1)
boxplot

# %%
#5 polygonal_papules
contigencyTable5= pd.crosstab(data1['polygonal_papules'],data1['class'])
contigencyTable5
# Out:
# class                1   2   3   4   5   6
# polygonal_papules
# 0                  112  61   3  49  52  20
# 1                    0   0   1   0   0   0
# 2                    0   0  41   0   0   0
# 3                    0   0  27   0   0   0

# %%
#5
# Plot the obtained results # polygonal_papules
boxplot=contigencyTable4.plot.bar(rot=1)
boxplot

# %%
#6 koebner_phenomenon
contigencyTable6= pd.crosstab(data1['koebner_phenomenon'],data1['class'])
contigencyTable6
# Out:
# class                1   2   3   4   5   6
# koebner_phenomenon
# 0                   63  60  20   9  52  20
# 1                   27   0  18  25   0   0
# 2                   18   1  23  12   0   0
# 3                    4   0  11   3   0   0

# %%
#6
# Plot the obtained results # polygonal_papules
boxplot=contigencyTable6.plot.bar(rot=1)
boxplot

# %%
#7 follicular_papules
contigencyTable7= pd.crosstab(data1['follicular_papules'],data1['class'])
contigencyTable7
# Out:
# class                 1   2   3   4   5   6
# follicular_papules
# 0                   109  60  72  49  43   0
# 1                     2   1   0   0   6   2
# 2                     1   0   0   0   3  12
# 3                     0   0   0   0   0   6

# %%
#7
# Plot the obtained results # follicular_papules
boxplot=contigencyTable7.plot.bar(rot=1)
boxplot

# %%
#8 oral_mucosal_involvement
contigencyTable8= pd.crosstab(data1['oral_mucosal_involvement'],data1['class'])
contigencyTable8
# Out:
# class                       1   2   3   4   5   6
# oral_mucosal_involvement
# 0                         112  61   5  49  52  20
# 1                           0   0   9   0   0   0
# 2                           0   0  45   0   0   0
# 3                           0   0  13   0   0   0

# %%
#8
# Plot the obtained results # oral_mucosal_involvement
boxplot=contigencyTable8.plot.bar(rot=1)
boxplot

# %%
#9 family_history
contigencyTable9= pd.crosstab(data1['family_history'],data1['class'])
contigencyTable9
# Out:
# class            1   2   3   4   5   6
# family_history
# 0               80  58  71  49  52  10
# 1               32   3   1   0   0  10

# %%
# 9Plot the obtained results # family_history
boxplot=contigencyTable9.plot.bar(rot=1)
boxplot

# %%
#10 melanin_incontinence 
contigencyTable10= pd.crosstab(data1['melanin_incontinence'],data1['class'])
contigencyTable10
# Out:
# class                   1   2   3   4   5   6
# melanin_incontinence
# 0                     112  61   2  49  52  20
# 1                       0   0   8   0   0   0
# 2                       0   0  46   0   0   0
# 3                       0   0  16   0   0   0

# %%
# 10Plot the obtained results # family_history
boxplot=contigencyTable10.plot.bar(rot=1)
boxplot

# %%
#11 melanin_incontinence 
contigencyTable11= pd.crosstab(data1['melanin_incontinence'],data1['class'])
contigencyTable11
# Out:
# class                   1   2   3   4   5   6
# melanin_incontinence
# 0                     112  61   2  49  52  20
# 1                       0   0   8   0   0   0
# 2                       0   0  46   0   0   0
# 3                       0   0  16   0   0   0

# %%
# 11Plot the obtained results # melanin_incontinence 
boxplot=contigencyTable11.plot.bar(rot=1)
boxplot

# %%
#12
#eosinophils_in_the_infiltrate
contigencyTable12= pd.crosstab(data1['eosinophils_in_the_infiltrate'],data1['class'])
contigencyTable12
# Out:
# class                            1   2   3   4   5   6
# eosinophils_in_the_infiltrate
# 0                              109  39  62  46  48  20
# 1                                2  16   8   3   4   0
# 2                                1   6   2   0   0   0

# %%
# 12Plot the obtained results # melanin_incontinence 
boxplot=contigencyTable12.plot.bar(rot=1)
boxplot

# %%
#13
#pnl_infiltrate 
contigencyTable13= pd.crosstab(data1['pnl_infiltrate'],data1['class'])
contigencyTable13
# Out:
# class            1   2   3   4   5   6
# pnl_infiltrate
# 0               34  17  72  43  52  17
# 1               37  23   0   6   0   3
# 2               35  20   0   0   0   0
# 3                6   1   0   0   0   0

# %%
# 13Plot the obtained results #  pnl_infiltrate
boxplot=contigencyTable13.plot.bar(rot=1)
boxplot

# %%
#14
#fibrosis_of_the_papillary_dermis 
contigencyTable14= pd.crosstab(data1['fibrosis_of_the_papillary_dermis'],data1['class'])
contigencyTable14
# Out:
# class                               1   2   3   4   5   6
# fibrosis_of_the_papillary_dermis
# 0                                 112  61  70  49   0  20
# 1                                   0   0   0   0   8   0
# 2                                   0   0   2   0  21   0
# 3                                   0   0   0   0  23   0

# %%
# 14Plot the obtained results #fibrosis_of_the_papillary_dermis
boxplot=contigencyTable14.plot.bar(rot=1)
boxplot

# %%
#15
#exocytosis
contigencyTable15= pd.crosstab(data1['exocytosis'],data1['class'])
contigencyTable15
# Out:
# class        1   2   3   4   5  6
# exocytosis
# 0           93   1   1   1  20  2
# 1            8   7   6   8  20  8
# 2           11  32  38  28  12  8
# 3            0  21  27  12   0  2

# %%
# 15Plot the obtained results #exocytosis
boxplot=contigencyTable15.plot.bar(rot=1)
boxplot

# %%
#16
#acanthosis
contigencyTable16= pd.crosstab(data1['acanthosis'],data1['class'])
contigencyTable16
# Out:
# class        1   2   3   4   5   6
# acanthosis
# 0            1   4   1   4   0   0
# 1           14  14   9  19   7   8
# 2           70  35  43  26  25  11
# 3           27   8  19   0  20   1

# %%
# 16Plot the obtained results #acanthosis
boxplot=contigencyTable16.plot.bar(rot=1)
boxplot

# %%
data1.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# pnl_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
#17
#hyperkeratosis
contigencyTable17= pd.crosstab(data1['hyperkeratosis'],data1['class'])
contigencyTable17
# Out:
# class            1   2   3   4   5   6
# hyperkeratosis
# 0               53  50  54  37  27   6
# 1               30  10  15   9  14  12
# 2               25   0   3   3  11   2
# 3                4   1   0   0   0   0

# %%
# 17Plot the obtained results #acanthosis
boxplot=contigencyTable17.plot.bar(rot=1)
boxplot

# %%
#18
#clubbing_of_the_rete_ridges 
contigencyTable18= pd.crosstab(data1['clubbing_of_the_rete_ridges'],data1['class'])
contigencyTable18
# Out:
# class                         1   2   3   4   5   6
# clubbing_of_the_rete_ridges
# 0                             3  61  72  49  49  18
# 1                            15   0   0   0   2   2
# 2                            60   0   0   0   1   0
# 3                            34   0   0   0   0   0

# %%
# 18Plot the obtained results clubbing_of_the_rete_ridges
boxplot=contigencyTable18.plot.bar(rot=1)
boxplot

# %%
#19
#elongation_of_the_rete_ridges
contigencyTable19= pd.crosstab(data1['elongation_of_the_rete_ridges'],data1['class'])
contigencyTable19
# Out:
# class                           1   2   3   4   5   6
# elongation_of_the_rete_ridges
# 0                               0  54  72  49   5  18
# 1                              11   4   0   0   6   2
# 2                              61   3   0   0  31   0
# 3                              40   0   0   0  10   0

# %%
# 19Plot the obtained results elongation_of_the_rete_ridges
boxplot=contigencyTable19.plot.bar(rot=1)
boxplot

# %%
#20
#elongation_of_the_rete_ridges
contigencyTable20= pd.crosstab(data1['disappearance_of_the_granular_layer'],data1['class'])
contigencyTable20
# Out:
# class                                 1   2   3   4   5   6
# disappearance_of_the_granular_layer
# 0                                    46  61  63  31  52  20
# 1                                    12   0   1  17   0   0
# 2                                    40   0   8   1   0   0
# 3                                    14   0   0   0   0   0

# %%
# 20Plot the obtained results disappearance_of_the_granular_layer
boxplot=contigencyTable20.plot.bar(rot=1)
boxplot

# %% [markdown]
# Create a new column disease_1 by extracting only those records where the Disease=1 (psoriasis) , assigning “1” for those rows in the newly created  column, and marking “0” for the rest.

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html
data1['disease_1'] = np.where(data1['class'] == 1,1,0)
#https://numpy.org/doc/stable/user/quickstart.html

# %%
data1
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
#linear regression model
# for disease_1 vs. age even though disease_1 is a categoric variable. Plot the regression line, and compute the MSE and r-squared values for the model

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
from sklearn.linear_model import LinearRegression
x = data1['age'].values.reshape(-1,1)
y = data1['disease_1'].values.reshape(-1,1)

# %%
new_lin_model = LinearRegression()#new model

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# Prepare X and y
X = data1.filter(['age','disease_1'], axis=1)
y = data1['disease_1']


# Let's do an 80-20 split
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, random_state=42, shuffle=True, train_size=0.80, stratify=y)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
def makeDTModel(criterion,X_train,y_train) :
  model = DecisionTreeClassifier(criterion = "gini", #criterion
                                         max_leaf_nodes=10,max_depth=3, #alter max leaf nodes and max_depth
                                         random_state = 120).fit(X_train, y_train)
  return model

# %%
# display text and graphic representation of a tree classifier
#displayTree(cart_classifier, X)
#displayTree(c5_classifier, X)

def displayTree(cart_classifier, X) :
  tree.plot_tree(cart_classifier, feature_names=X.columns.values.tolist(),filled = True)    
  print(tree.export_text(cart_classifier,feature_names=X.columns.values.tolist()))# wrap this line with the print keyword

# %%
#cart_classifier = makeDTModel("gini", X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-b4a15315658e> in <module>()
# ----> 1 cart_classifier = makeDTModel("gini", X_train, y_train)
#
# <ipython-input-118-8a4d1de91273> in makeDTModel(criterion, X_train, y_train)
#       4   model = DecisionTreeClassifier(criterion = "gini", #criterion
#       5                                          max_leaf_nodes=10,max_depth=3, #alter max leaf nodes and max_depth
# ----> 6                                          random_state = 120).fit(X_train, y_train)
#       7   return model
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# ...

# %%
# display text and heatmap of a confusion matrix
#displayCM(cart_classifier, X_train, y_train, X_test, y_test)
#displayCM(c5_classifier, X_train, y_train, X_test, y_test)
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
def displayCM(cart_classifier, X_train, y_train, X_test, y_test):
  cart_predictions = cart_classifier.predict(X_test)
  cart_cm = confusion_matrix(y_true=y_test, 
                           y_pred = cart_predictions)
  plt.figure(figsize=(8,8))
  sns.heatmap(cart_cm, annot=True, 
            linewidths=.5, square = True, cmap = 'Oranges_r', fmt='0.4g');
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')
  print(cart_cm)

# %%
#displayCM(cart_classifier, X_train, y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-824235ad1dd2> in <module>()
# ----> 1 displayCM(cart_classifier, X_train, y_train, X_test, y_test)
#
# NameError: name 'cart_classifier' is not defined

# %%
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
# One-hot encode the data using pandas get_dummies
features = pd.get_dummies(data1)
# Display the first 5 rows of the last 12 columns
features.iloc[:,5:].head(5)
# Out:
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  family_history  \
# 0                           1                  0               0
# 1                           1                  1               1
# 2                           0                  0               0
# 3                           3                  2               0
# 4                           0                  0               0
#
#    melanin_incontinence  eosinophils_in_the_infiltrate  pnl_infiltrate  \
# 0                     0                              0               0
# ...

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-44e86bffe4bb> in <module>()
#       2 from sklearn.model_selection import train_test_split
#       3 # Split the data into training and testing sets
# ----> 4 train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)
#
# NameError: name 'labels' is not defined

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# %%
#summary

# %% [markdown]
# this data examined instances of dermatology cancer occurrences. First we cleaned up the data and examined the distriction of disease and age. Then a new column was made and we made models using the 3 fold cross violation.
